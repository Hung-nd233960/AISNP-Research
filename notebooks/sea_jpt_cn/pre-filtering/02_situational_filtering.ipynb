# %%
from notebook_init import setup
cfg, PATHS, POPULATIONS, HARD_FILTERS, SITUATIONAL_FILTERS, ML = setup()

cfg.print_config_summary()
print("\nSITUATIONAL FILTER SETTINGS")
print("="*60)
print(f"HWE threshold: {SITUATIONAL_FILTERS.HWE_P_THRESHOLD} (ADJUSTABLE)")
print(f"LD window: {SITUATIONAL_FILTERS.LD_WINDOW_KB}kb (ADJUSTABLE)")
print(f"LD step: {SITUATIONAL_FILTERS.LD_STEP} (ADJUSTABLE)")
print(f"LD R² threshold: {SITUATIONAL_FILTERS.LD_R2_THRESHOLD} (ADJUSTABLE)")
# Out:
# Working directory: /home/ibmelab/Projects/AISNP-Research
# ============================================================
# CONFIGURATION SUMMARY
# ============================================================
#
# --- PATHS ---
#   Config name:    sea_jpt_cn
#   Output dir:     data/1000genomes/output_sea_jpt_cn
#   VCF dir:        data/1000genomes/vcf_sea_jpt_cn
#   Samples CSV:    data/1000genomes/SEA_JPT_CN_subpopulation_samples.csv
#
# --- HARD FILTERS (Always Applied) ---
#   SNP-only:      True
#   Max alleles:   2
#   Min AF:        0.000992063492063492
#   Min call rate: 0.95
#
# --- SITUATIONAL FILTERS (Context-Dependent) ---
#   HWE threshold: 1e-06
#   HWE mode:      keep-fewhet
#   LD window:     1000kb
#   LD step:       1
#   LD R² cutoff:  0.1
#   FST top N:     1000
#
# --- POPULATIONS ---
#   Config name:    sea_jpt_cn
#   Raw subpops:    ('CHB', 'JPT', 'CHS', 'CDX', 'KHV')
#   Target pops:    ('CN', 'JPT', 'SEA')
#   Merge mapping:  {'CHB': 'CN', 'CHS': 'CN', 'JPT': 'JPT', 'KHV': 'SEA', 'CDX': 'SEA'}
#   Num samples:    504
# ============================================================
#
# SITUATIONAL FILTER SETTINGS
# ============================================================
# HWE threshold: 1e-06 (ADJUSTABLE)
# LD window: 1000kb (ADJUSTABLE)
# LD step: 1 (ADJUSTABLE)
# LD R² threshold: 0.1 (ADJUSTABLE)

# %%
# Input from hard filtering
INPUT_PFILE = str(PATHS.PLINK_MAF_FILTERED)
print(f"Input: {INPUT_PFILE}")
print(f"Variants: {count_variants(INPUT_PFILE)}")
# Out:
# Input: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered
# Variants: 21981924

# %% [markdown]
# ## Step 1: Hardy-Weinberg Equilibrium Analysis
#
# **SITUATIONAL FILTER 1**: HWE filter removes variants with significant deviation from expected genotype frequencies.
#
# ### When to adjust HWE threshold:
# - **Population genetics** (ancestry, structure): Use relaxed threshold (1e-6)
# - **GWAS controls**: Use strict threshold (1e-10)
# - **Admixed populations**: May need to skip or use very relaxed threshold

# %%
# Calculate HWE statistics
hwe_prefix = calculate_hwe_stats(
    INPUT_PFILE,
    output_prefix=f"{INPUT_PFILE}_hardy",
)
# Out:
# Calculating HWE statistics: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered_hardy.hardy
# Running: plink2 --threads 16 --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered --hardy --out data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered_hardy
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered_hardy.log.
# Options in effect:
#   --hardy
#   --out data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered_hardy
#   --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered
#   --threads 16
#
# Start time: Sun May 24 10:36:45 2026
# 15186 MiB RAM detected, ~7988 available; reserving 7593 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 504 samples (0 females, 0 males, 504 ambiguous; 504 founders) loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered.psam.
# 21981924 variants loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered.pvar.
# Note: No phenotype data present.
# Calculating allele frequencies... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# --hardy: Autosomal Hardy-Weinberg report (founders only) written %
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered_hardy.hardy
# .
# End time: Sun May 24 10:36:54 2026

# %%
# Analyze HWE results
hardy_file = f"{hwe_prefix}.hardy"
hardy_df, hardy_summary = analyze_hardy(
    hardy_file,
    p_threshold=SITUATIONAL_FILTERS.HWE_P_THRESHOLD,
)

print(f"\nSummary:")
print(f"  Total variants: {hardy_summary['num_variants']}")
print(f"  HWE failures (P < {SITUATIONAL_FILTERS.HWE_P_THRESHOLD}): {hardy_summary['hwe_fail_variants']}")
print(f"  HWE failure rate: {hardy_summary['hwe_fail_pct']:.4f}%")
# Out:
# Loading HWE results: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered_hardy.hardy
# Loaded 21981924 variants.
#   #CHROM             ID A1 AX  HOM_A1_CT  HET_A1_CT  TWO_AX_CT  O(HET_A1)  \
# 0      1  1:10542:\C:\T  C  T        503          1          0   0.001984
# 1      1  1:10642:\G:\A  G  A        501          3          0   0.005952
# 2      1  1:11008:\C:\G  C  G        467         37          0   0.073413
# 3      1  1:11012:\C:\G  C  G        467         37          0   0.073413
# 4      1  1:13110:\G:\A  G  A        502          2          0   0.003968
#
#    E(HET_A1)    P
# 0   0.001982  1.0
# 1   0.005935  1.0
# 2   0.070718  1.0
# 3   0.070718  1.0
# 4   0.003960  1.0
#
# --- HWE QC Summary ---
# Variants failing HWE (P < 1e-06): 72667 (0.3306%)
#
# Summary:
#   Total variants: 21981924
#   HWE failures (P < 1e-06): 72667
#   HWE failure rate: 0.3306%

# %%
# Visualize HWE p-value distribution
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# P-value histogram (log scale)
p_values = hardy_df['P'].dropna()
log_p = -np.log10(p_values + 1e-300)  # Add small value to avoid log(0)

axes[0].hist(log_p, bins=50, edgecolor='black', alpha=0.7)
axes[0].axvline(-np.log10(SITUATIONAL_FILTERS.HWE_P_THRESHOLD), 
                color='red', linestyle='--', 
                label=f'Threshold: P < {SITUATIONAL_FILTERS.HWE_P_THRESHOLD}')
axes[0].set_xlabel('-log10(P-value)')
axes[0].set_ylabel('Count')
axes[0].set_title('HWE P-value Distribution')
axes[0].legend()

# Observed vs Expected heterozygosity
axes[1].scatter(
    hardy_df['E(HET_A1)'], 
    hardy_df['O(HET_A1)'], 
    alpha=0.3, s=5
)
axes[1].plot([0, 1], [0, 1], 'r--', label='y=x (HWE expectation)')
axes[1].set_xlabel('Expected Heterozygosity')
axes[1].set_ylabel('Observed Heterozygosity')
axes[1].set_title('Observed vs Expected Heterozygosity')
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_97808/1081678781.py:29: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /home/ibmelab/miniforge3/envs/aisnp/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Apply HWE filter
hwe_output = filter_hwe(
    INPUT_PFILE,
    output_pfile=str(PATHS.PLINK_HWE_FILTERED),
    p_threshold=SITUATIONAL_FILTERS.HWE_P_THRESHOLD,
    verbose=True,
)
# Out:
# ============================================================
# SITUATIONAL FILTER 1: Hardy-Weinberg Equilibrium
# ============================================================
#   P-value threshold: 1e-06
#   Filter mode: keep-fewhet
#   Note: This is SITUATIONAL - adjust threshold based on study design
#   Input variants: 21981924
# Running: plink2 --threads 16 --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered --hwe 1e-06 keep-fewhet --make-pgen --out data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered.log.
# Options in effect:
#   --hwe 1e-06 keep-fewhet
#   --make-pgen
#   --out data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered
#   --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered
#   --threads 16
#
# Start time: Sun May 24 10:39:34 2026
# 15186 MiB RAM detected, ~5189 available; reserving 5125 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 504 samples (0 females, 0 males, 504 ambiguous; 504 founders) loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered.psam.
# 21981924 variants loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_AND_SNP_filtered_data_MAF_filtered.pvar.
# Note: No phenotype data present.
# Calculating allele frequencies... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# --hwe keep-fewhet: 36778 variants removed due to Hardy-Weinberg exact test
# (founders only).
# 21945146 variants remaining after main filters.
# Writing data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered.psam
# ... done.
# Writing data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered.pvar
# ... .
# Writing data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered.pgen
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# End time: Sun May 24 10:39:47 2026
#
# Output: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered
#   Output variants: 21945146
#   Removed for HWE deviation: 36778

# %% [markdown]
# ## Step 2: Variant ID Standardization
#
# Set standardized variant IDs for cross-study compatibility and FST analysis.
#
# Format: `chrom:pos[build]ref,alt` (e.g., `12:58124534[b37]C,G`)

# %%
# Set variant IDs
unique_ids_output = set_variant_ids(
    hwe_output,
    output_pfile=str(PATHS.PLINK_UNIQUE_IDS),
    id_format="@:#[b37]$r,$a",
    verbose=True,
)
# Out:
# ============================================================
# SITUATIONAL: Variant ID Standardization
# ============================================================
#   ID format: @:#[b37]$r,$a
# Running: plink2 --threads 16 --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered --set-all-var-ids @:#[b37]$r,$a --make-pgen --out data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.log.
# Options in effect:
#   --make-pgen
#   --out data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids
#   --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered
#   --set-all-var-ids @:#[b37]$r,$a
#   --threads 16
#
# Start time: Sun May 24 10:39:52 2026
# 15186 MiB RAM detected, ~5164 available; reserving 5100 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 504 samples (0 females, 0 males, 504 ambiguous; 504 founders) loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered.psam.
# 21945146 variants loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered.pvar.
# Note: No phenotype data present.
# Writing
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.psam
# ... done.
# Writing
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.pvar
# ... .
# Writing
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.pgen
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# End time: Sun May 24 10:40:06 2026
#
# Output: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids

# %% [markdown]
# ## Step 3: LD Pruning
#
# **SITUATIONAL FILTER 2**: Remove variants in high linkage disequilibrium.
#
# ### When to adjust LD parameters:
# - **PCA/Structure analysis**: Aggressive pruning (window=1000kb, r²=0.1)
# - **Ancestry inference**: Moderate pruning (window=500kb, r²=0.2)
# - **Association studies**: Usually SKIP LD pruning
#
# ### Parameters:
# - **Window**: Size of sliding window in kb
# - **Step**: Number of variants to move window
# - **R² threshold**: Maximum correlation allowed

# %%
# Test multiple LD configurations
ld_configs = [
    {"window": 1000, "step": 1, "r2": 0.1, "name": "aggressive"},
    {"window": 500, "step": 1, "r2": 0.2, "name": "moderate"},
    {"window": 100, "step": 1, "r2": 0.5, "name": "light"},
]

ld_results = {}

for config in ld_configs:
    print(f"\n>>> Testing {config['name']} LD pruning...")
    prefix = calculate_ld_prune_list(
        unique_ids_output,
        output_prefix=f"{str(PATHS.OUTPUT_DIR)}/LD_test_{config['name']}",
        window_kb=config['window'],
        step=config['step'],
        r2_threshold=config['r2'],
        verbose=True,
    )
    
    # Count variants
    with open(f"{prefix}.prune.in") as f:
        n_keep = sum(1 for _ in f)
    ld_results[config['name']] = n_keep
# Out:
# >>> Testing aggressive LD pruning...
# ============================================================
# SITUATIONAL FILTER 3: LD Pruning (Calculate List)
# ============================================================
#   Window: 1000 kb
#   Step: 1 SNPs
#   R² threshold: 0.1
#   Note: This is SITUATIONAL - skip for association studies
# Running: plink2 --threads 16 --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids --indep-pairwise 1000kb 1 0.1 --out data/1000genomes/output_sea_jpt_cn/LD_test_aggressive
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/1000genomes/output_sea_jpt_cn/LD_test_aggressive.log.
# Options in effect:
#   --indep-pairwise 1000kb 1 0.1
#   --out data/1000genomes/output_sea_jpt_cn/LD_test_aggressive
#   --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids
#   --threads 16
#
# Start time: Sun May 24 10:40:06 2026
# 15186 MiB RAM detected, ~5213 available; reserving 5149 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 504 samples (0 females, 0 males, 504 ambiguous; 504 founders) loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.psam.
# 21945146 variants loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.pvar.
# Note: No phenotype data present.
# Calculating allele frequencies... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# --indep-pairwise (15 compute threads): 12162125293338424650545963677176808488929721330387/21945146 variants removed.
# Variant lists written to
# data/1000genomes/output_sea_jpt_cn/LD_test_aggressive.prune.in and
# data/1000genomes/output_sea_jpt_cn/LD_test_aggressive.prune.out .
# End time: Sun May 24 10:40:27 2026
#
# Variants to keep: 614759
# Prune list: data/1000genomes/output_sea_jpt_cn/LD_test_aggressive.prune.in
#
# >>> Testing moderate LD pruning...
# ============================================================
# SITUATIONAL FILTER 3: LD Pruning (Calculate List)
# ============================================================
#   Window: 500 kb
#   Step: 1 SNPs
#   R² threshold: 0.2
#   Note: This is SITUATIONAL - skip for association studies
# Running: plink2 --threads 16 --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids --indep-pairwise 500kb 1 0.2 --out data/1000genomes/output_sea_jpt_cn/LD_test_moderate
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/1000genomes/output_sea_jpt_cn/LD_test_moderate.log.
# Options in effect:
#   --indep-pairwise 500kb 1 0.2
#   --out data/1000genomes/output_sea_jpt_cn/LD_test_moderate
#   --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids
#   --threads 16
#
# Start time: Sun May 24 10:40:27 2026
# 15186 MiB RAM detected, ~5170 available; reserving 5106 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 504 samples (0 females, 0 males, 504 ambiguous; 504 founders) loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.psam.
# 21945146 variants loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.pvar.
# Note: No phenotype data present.
# Calculating allele frequencies... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# --indep-pairwise (15 compute threads): 12162125293338424650545963677176808488929720115971/21945146 variants removed.
# Variant lists written to
# data/1000genomes/output_sea_jpt_cn/LD_test_moderate.prune.in and
# data/1000genomes/output_sea_jpt_cn/LD_test_moderate.prune.out .
# End time: Sun May 24 10:40:52 2026
#
# Variants to keep: 1829175
# Prune list: data/1000genomes/output_sea_jpt_cn/LD_test_moderate.prune.in
#
# >>> Testing light LD pruning...
# ============================================================
# SITUATIONAL FILTER 3: LD Pruning (Calculate List)
# ============================================================
#   Window: 100 kb
#   Step: 1 SNPs
#   R² threshold: 0.5
#   Note: This is SITUATIONAL - skip for association studies
# Running: plink2 --threads 16 --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids --indep-pairwise 100kb 1 0.5 --out data/1000genomes/output_sea_jpt_cn/LD_test_light
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/1000genomes/output_sea_jpt_cn/LD_test_light.log.
# Options in effect:
#   --indep-pairwise 100kb 1 0.5
#   --out data/1000genomes/output_sea_jpt_cn/LD_test_light
#   --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids
#   --threads 16
#
# Start time: Sun May 24 10:40:52 2026
# 15186 MiB RAM detected, ~5145 available; reserving 5081 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 504 samples (0 females, 0 males, 504 ambiguous; 504 founders) loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.psam.
# 21945146 variants loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.pvar.
# Note: No phenotype data present.
# Calculating allele frequencies... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# --indep-pairwise (15 compute threads): 131722263135404449535862677176808589949812918583/21945146 variants removed.
# Variant lists written to
# data/1000genomes/output_sea_jpt_cn/LD_test_light.prune.in and
# data/1000genomes/output_sea_jpt_cn/LD_test_light.prune.out .
# End time: Sun May 24 10:41:18 2026
#
# Variants to keep: 9026563
# Prune list: data/1000genomes/output_sea_jpt_cn/LD_test_light.prune.in

# %%
# Compare LD pruning results
print("\nLD Pruning Comparison:")
print("="*60)
input_n = count_variants(unique_ids_output)
print(f"Input variants: {input_n}")
print()
for name, n_keep in ld_results.items():
    pct_keep = n_keep / input_n * 100
    print(f"  {name:15s}: {n_keep:,} variants ({pct_keep:.1f}% retained)")
# Out:
# LD Pruning Comparison:
# ============================================================
# Input variants: 21945146
#
#   aggressive     : 614,759 variants (2.8% retained)
#   moderate       : 1,829,175 variants (8.3% retained)
#   light          : 9,026,563 variants (41.1% retained)

# %%
# Visualize LD pruning results
plt.figure(figsize=(10, 5))

names = list(ld_results.keys())
values = list(ld_results.values())

bars = plt.bar(names, values, color=['red', 'orange', 'green'], edgecolor='black')
plt.axhline(input_n, color='blue', linestyle='--', label=f'Input: {input_n:,}')

for bar, val in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5000, 
             f'{val:,}', ha='center', va='bottom')

plt.xlabel('LD Pruning Strategy')
plt.ylabel('Variants Retained')
plt.title('Effect of Different LD Pruning Strategies')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Apply aggressive LD pruning (recommended for FST/PCA)
ld_output = filter_ld(
    unique_ids_output,
    output_pfile=str(PATHS.PLINK_LD_PRUNED),
    window_kb=SITUATIONAL_FILTERS.LD_WINDOW_KB,
    step=SITUATIONAL_FILTERS.LD_STEP,
    r2_threshold=SITUATIONAL_FILTERS.LD_R2_THRESHOLD,
    verbose=True,
)
# Out:
# ============================================================
# SITUATIONAL FILTER 3: LD Pruning (Calculate List)
# ============================================================
#   Window: 1000 kb
#   Step: 1 SNPs
#   R² threshold: 0.1
#   Note: This is SITUATIONAL - skip for association studies
# Running: plink2 --threads 16 --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids --indep-pairwise 1000kb 1 0.1 --out data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids_LD_pruned_1000kb_1_0.1
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids_LD_pruned_1000kb_1_0.1.log.
# Options in effect:
#   --indep-pairwise 1000kb 1 0.1
#   --out data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids_LD_pruned_1000kb_1_0.1
#   --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids
#   --threads 16
#
# Start time: Sun May 24 10:41:25 2026
# 15186 MiB RAM detected, ~5273 available; reserving 5209 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 504 samples (0 females, 0 males, 504 ambiguous; 504 founders) loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.psam.
# 21945146 variants loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.pvar.
# Note: No phenotype data present.
# Calculating allele frequencies... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# --indep-pairwise (15 compute threads): 12162125293338424650545963677176808488929721330387/21945146 variants removed.
# Variant lists written to
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids_LD_pruned_1000kb_1_0.1.prune.in
# and
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids_LD_pruned_1000kb_1_0.1.prune.out
# .
# End time: Sun May 24 10:41:47 2026
#
# Variants to keep: 614759
# Prune list: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids_LD_pruned_1000kb_1_0.1.prune.in
# Applying LD pruning from: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids_LD_pruned_1000kb_1_0.1.prune.in
#   Input variants: 21945146
# Running: plink2 --threads 16 --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids --extract data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids_LD_pruned_1000kb_1_0.1.prune.in --make-pgen --out data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST.log.
# Options in effect:
#   --extract data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids_LD_pruned_1000kb_1_0.1.prune.in
#   --make-pgen
#   --out data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST
#   --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids
#   --threads 16
#
# Start time: Sun May 24 10:41:51 2026
# 15186 MiB RAM detected, ~5183 available; reserving 5119 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 504 samples (0 females, 0 males, 504 ambiguous; 504 founders) loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.psam.
# 21945146 variants loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.pvar.
# Note: No phenotype data present.
# --extract: 614759 variants remaining.
# 614759 variants remaining after main filters.
# Writing data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST.psam
# ... done.
# Writing data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST.pvar
# ... .
# Writing data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST.pgen
# ... 316395done.
# End time: Sun May 24 10:41:58 2026
#
# Output: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST
#   Output variants: 614759

# %% [markdown]
# ## Summary

# %%
print("="*60)
print("SITUATIONAL FILTERING SUMMARY")
print("="*60)
print(f"\nFilters applied:")
print(f"  1. HWE (P < {SITUATIONAL_FILTERS.HWE_P_THRESHOLD}): SITUATIONAL")
print(f"  2. Variant ID standardization")
print(f"  3. LD pruning ({SITUATIONAL_FILTERS.LD_WINDOW_KB}kb, r²={SITUATIONAL_FILTERS.LD_R2_THRESHOLD}): SITUATIONAL")
print(f"\nVariant counts:")
print(f"  Input (after hard filters): {count_variants(INPUT_PFILE)}")
print(f"  After HWE: {count_variants(hwe_output)}")
print(f"  After LD pruning: {count_variants(ld_output)}")
print(f"\nOutput file: {ld_output}")
print(f"\nNext step: Run 03_fst_and_pca.ipynb")
# Out:
# ============================================================
# SITUATIONAL FILTERING SUMMARY
# ============================================================
#
# Filters applied:
#   1. HWE (P < 1e-06): SITUATIONAL
#   2. Variant ID standardization
#   3. LD pruning (1000kb, r²=0.1): SITUATIONAL
#
# Variant counts:
#   Input (after hard filters): 21981924
#   After HWE: 21945146
#   After LD pruning: 614759
#
# Output file: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST
#
# Next step: Run 03_fst_and_pca.ipynb
