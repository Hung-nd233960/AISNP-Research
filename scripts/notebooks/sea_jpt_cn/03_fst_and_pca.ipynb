# %%
# Add scripts to path and fix working directory
import sys
import os
from pathlib import Path

# Change to project root (two levels up from notebook)
_root = Path.cwd()
while not (_root / 'scripts' / 'config.py').exists():
    if _root == _root.parent:
        raise RuntimeError("Cannot find project root - launch Jupyter from the project directory")
    _root = _root.parent
project_root = _root
os.chdir(project_root)
sys.path.insert(0, str(project_root / "scripts"))

print(f"Working directory: {os.getcwd()}")

# Import config module and set population FIRST
import config as cfg
cfg.set_population_config("sea_jpt_cn")

# Now create aliases (pointing to updated config)
PATHS = cfg.PATHS
SITUATIONAL_FILTERS = cfg.SITUATIONAL_FILTERS
POPULATIONS = cfg.POPULATIONS

# Import other modules
from utils import analyze_fst, merge_fst_top_variants, variants_to_bed_file, count_variants
from fst_selection import (
    add_population_to_psam,
    calculate_pairwise_fst,
    find_fst_files,
    analyze_all_fst_files,
    select_top_fst_variants,
    extract_fst_variants,
)
from situational_filters import calculate_pca

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Working directory: /home/ibmelab/Projects/AISNP-Research

# %%
# Configuration
INPUT_PFILE = str(PATHS.PLINK_LD_PRUNED)
SAMPLES_CSV = str(PATHS.EAS_SAMPLES_CSV)
OUTPUT_DIR = str(PATHS.OUTPUT_DIR)

print(f"Input pfile: {INPUT_PFILE}")
print(f"Samples CSV: {SAMPLES_CSV}")
print(f"FST top N: {SITUATIONAL_FILTERS.FST_TOP_N}")
print(f"Variants: {count_variants(INPUT_PFILE)}")
# Out:
# Input pfile: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST
# Samples CSV: data/1000genomes/SEA_JPT_CN_subpopulation_samples.csv
# FST top N: 1000
# Variants: 614759

# %% [markdown]
# ## Step 1: Add Population Labels to PSAM
#
# FST calculation requires population labels in the .psam file.

# %%
# Add population labels
psam_path = f"{INPUT_PFILE}.psam"

# Create a backup first
import shutil
backup_path = f"{psam_path}.backup"
if not os.path.exists(backup_path):
    shutil.copy(psam_path, backup_path)
    print(f"Backup created: {backup_path}")

# Add population labels
add_population_to_psam(
    psam_path,
    SAMPLES_CSV,
    output_path=psam_path,
)

# Verify
psam_df = pd.read_csv(psam_path, sep="\t")
print("\nUpdated .psam file:")
display(psam_df.head())
print(f"\nPopulation counts:")
display(psam_df['pop'].value_counts())
# Out:
# Backup created: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST.psam.backup
# Added population labels to psam file
#   Samples: 504
#   Populations: {'CN': 208, 'SEA': 192, 'JPT': 104}
#
# Updated .psam file:
#       #IID pop
# 0  HG00403  CN
# 1  HG00404  CN
# 2  HG00406  CN
# 3  HG00407  CN
# 4  HG00409  CN
# Population counts:
# pop
# CN     208
# SEA    192
# JPT    104
# Name: count, dtype: int64

# %% [markdown]
# ## Step 2: Calculate Pairwise FST
#
# FST (Fixation Index) measures genetic differentiation between populations.
# - FST = 0: No differentiation (same allele frequencies)
# - FST = 1: Complete differentiation (fixed for different alleles)

# %%
# Calculate FST
fst_prefix = calculate_pairwise_fst(
    INPUT_PFILE,
    output_prefix=str(PATHS.FST_RESULTS),
    pop_column="pop",
)
# Out:
# ============================================================
# FST CALCULATION
# ============================================================
#   Input: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST
#   Population column: pop
# Running: plink2 --threads 16 --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST --fst pop report-variants --out data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FST_RESULTS
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FST_RESULTS.log.
# Options in effect:
#   --fst pop report-variants
#   --out data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FST_RESULTS
#   --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST
#   --threads 16
#
# Start time: Sun May 24 14:14:45 2026
# 15186 MiB RAM detected, ~5408 available; reserving 5344 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 504 samples (0 females, 0 males, 504 ambiguous; 504 founders) loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST.psam.
# 614759 variants loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FINAL_DATA_FOR_FST.pvar.
# 1 categorical phenotype loaded (504 values).
# --fst: Analyzing 504 samples across 3 populations.
# Autosomal --fst: 102131425363748595done.
# Autosomal --fst: 3 .fst.var files written.
# Autosomal --fst: Summary written to
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FST_RESULTS.fst.summary .
# End time: Sun May 24 14:14:45 2026
#
# FST files created: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FST_RESULTS.*

# %%
# Find FST files
fst_files = find_fst_files(fst_prefix)

# List pairwise comparisons
print("\nPairwise FST comparisons:")
for f in fst_files:
    print(f"  - {os.path.basename(f)}")
# Out:
# Found 3 FST files:
#   - SEA_JPT_CN_FST_RESULTS.CN.SEA.fst.var
#   - SEA_JPT_CN_FST_RESULTS.JPT.SEA.fst.var
#   - SEA_JPT_CN_FST_RESULTS.CN.JPT.fst.var
#
# Pairwise FST comparisons:
#   - SEA_JPT_CN_FST_RESULTS.CN.SEA.fst.var
#   - SEA_JPT_CN_FST_RESULTS.JPT.SEA.fst.var
#   - SEA_JPT_CN_FST_RESULTS.CN.JPT.fst.var

# %% [markdown]
# ## Step 3: Analyze FST Distribution

# %%
# Analyze all FST files
all_fst, top_fst = analyze_all_fst_files(
    fst_prefix,
    top_n=SITUATIONAL_FILTERS.FST_TOP_N,
    plot=False,
)
# Out:
# Found 3 FST files:
#   - SEA_JPT_CN_FST_RESULTS.CN.SEA.fst.var
#   - SEA_JPT_CN_FST_RESULTS.JPT.SEA.fst.var
#   - SEA_JPT_CN_FST_RESULTS.CN.JPT.fst.var
#
# Analyzing: CN.SEA
# Loading FST file: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FST_RESULTS.CN.SEA.fst.var
#    #CHROM    POS               ID  OBS_CT  HUDSON_FST
# 0       1  13116  1:13116[b37]T,G     400   -0.002387
# 1       1  13273  1:13273[b37]G,C     400    0.011534
# 2       1  13289  1:13289[b37]C,T     400   -0.001508
# 3       1  13543  1:13543[b37]T,G     400   -0.001508
# 4       1  14599  1:14599[b37]T,A     400   -0.001660
#               #CHROM           POS    OBS_CT     HUDSON_FST
# count  614759.000000  6.147590e+05  614759.0  600662.000000
# mean        9.093952  7.787213e+07     400.0       0.002505
# std         6.027900  5.847665e+07       0.0       0.006675
# min         1.000000  6.840000e+02     400.0      -0.002510
# 25%         4.000000  2.894938e+07     400.0      -0.001822
# 50%         8.000000  6.717207e+07     400.0       0.000000
# 75%        14.000000  1.163766e+08     400.0       0.004819
# max        22.000000  2.492402e+08     400.0       0.285170
# Total variants: 614759
# NaN FST: 14097
# Negative FST: 273714
# Zero FST: 28355
# Positive FST: 298593
#
# Top 1000 variants:
#         #CHROM        POS                   ID  OBS_CT  HUDSON_FST
# 574876      19   54792079  19:54792079[b37]G,T     400    0.285170
# 147137       4   17813761   4:17813761[b37]G,A     400    0.222120
# 120391       3   86028382   3:86028382[b37]G,T     400    0.216326
# 4028         1   12387655   1:12387655[b37]G,A     400    0.200381
# 131542       3  152553769  3:152553769[b37]C,T     400    0.196495
#
# Analyzing: JPT.SEA
# Loading FST file: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FST_RESULTS.JPT.SEA.fst.var
#    #CHROM    POS               ID  OBS_CT  HUDSON_FST
# 0       1  13116  1:13116[b37]T,G     296    0.047274
# 1       1  13273  1:13273[b37]G,C     296    0.072630
# 2       1  13289  1:13289[b37]C,T     296    0.002611
# 3       1  13543  1:13543[b37]T,G     296    0.002611
# 4       1  14599  1:14599[b37]T,A     296    0.051634
#               #CHROM           POS    OBS_CT     HUDSON_FST
# count  614759.000000  6.147590e+05  614759.0  589780.000000
# mean        9.093952  7.787213e+07     296.0       0.007057
# std         6.027900  5.847665e+07       0.0       0.014378
# min         1.000000  6.840000e+02     296.0      -0.003727
# 25%         4.000000  2.894938e+07     296.0      -0.001379
# 50%         8.000000  6.717207e+07     296.0       0.002611
# 75%        14.000000  1.163766e+08     296.0       0.009662
# max        22.000000  2.492402e+08     296.0       0.386240
# Total variants: 614759
# NaN FST: 24979
# Negative FST: 185273
# Zero FST: 53704
# Positive FST: 350803
#
# Top 1000 variants:
#         #CHROM        POS                    ID  OBS_CT  HUDSON_FST
# 225262       6   31603591    6:31603591[b37]A,G     296    0.386240
# 574876      19   54792079   19:54792079[b37]G,T     296    0.347395
# 537163      17   72054724   17:72054724[b37]C,T     296    0.254177
# 476047      14  106286458  14:106286458[b37]A,G     296    0.250414
# 580886      20   12928988   20:12928988[b37]T,G     296    0.250124
#
# Analyzing: CN.JPT
# Loading FST file: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FST_RESULTS.CN.JPT.fst.var
#    #CHROM    POS               ID  OBS_CT  HUDSON_FST
# 0       1  13116  1:13116[b37]T,G     312    0.044101
# 1       1  13273  1:13273[b37]G,C     312    0.027190
# 2       1  13289  1:13289[b37]C,T     312    0.000000
# 3       1  13543  1:13543[b37]T,G     312    0.000000
# 4       1  14599  1:14599[b37]T,A     312    0.064178
#               #CHROM           POS    OBS_CT     HUDSON_FST
# count  614759.000000  6.147590e+05  614759.0  589349.000000
# mean        9.093952  7.787213e+07     312.0       0.003988
# std         6.027900  5.847665e+07       0.0       0.009865
# min         1.000000  6.840000e+02     312.0      -0.003620
# 25%         4.000000  2.894938e+07     312.0      -0.002402
# 50%         8.000000  6.717207e+07     312.0       0.000642
# 75%        14.000000  1.163766e+08     312.0       0.006293
# max        22.000000  2.492402e+08     312.0       0.203482
# Total variants: 614759
# NaN FST: 25410
# Negative FST: 214351
# Zero FST: 48874
# Positive FST: 326124
#
# Top 1000 variants:
#         #CHROM       POS                   ID  OBS_CT  HUDSON_FST
# 507284      16  46426674  16:46426674[b37]T,C     312    0.203482
# 120206       3  83842624   3:83842624[b37]G,A     312    0.196357
# 603341      21  47054067  21:47054067[b37]A,G     312    0.191094
# 526427      17  22261227  17:22261227[b37]G,A     312    0.177473
# 601646      21  42335080  21:42335080[b37]C,G     312    0.173854

# %%
# Visualize FST distributions
n_comparisons = len(all_fst)
fig, axes = plt.subplots(1, n_comparisons, figsize=(5*n_comparisons, 4))

if n_comparisons == 1:
    axes = [axes]

for ax, (comparison, df) in zip(axes, all_fst.items()):
    fst_valid = df['HUDSON_FST'].dropna()
    fst_positive = fst_valid[fst_valid > 0]
    
    ax.hist(fst_positive, bins=50, edgecolor='black', alpha=0.7)
    ax.set_xlabel('Hudson FST')
    ax.set_ylabel('Count')
    ax.set_title(f'{comparison}\n(mean={fst_positive.mean():.4f})')

plt.tight_layout()
plt.suptitle('FST Distribution by Population Pair', y=1.02)
plt.show()

# %%
# Summary statistics for each comparison
print("FST Summary Statistics:")
print("="*60)

for comparison, df in all_fst.items():
    fst_valid = df['HUDSON_FST'].dropna()
    fst_positive = fst_valid[fst_valid > 0]
    
    print(f"\n{comparison}:")
    print(f"  Total variants: {len(df)}")
    print(f"  Valid FST: {len(fst_valid)}")
    print(f"  Positive FST: {len(fst_positive)}")
    print(f"  Mean FST: {fst_positive.mean():.6f}")
    print(f"  Max FST: {fst_positive.max():.6f}")
# Out:
# FST Summary Statistics:
# ============================================================
#
# CN.SEA:
#   Total variants: 614759
#   Valid FST: 600662
#   Positive FST: 298593
#   Mean FST: 0.006622
#   Max FST: 0.285170
#
# JPT.SEA:
#   Total variants: 614759
#   Valid FST: 589780
#   Positive FST: 350803
#   Mean FST: 0.013243
#   Max FST: 0.386240
#
# CN.JPT:
#   Total variants: 614759
#   Valid FST: 589349
#   Positive FST: 326124
#   Mean FST: 0.008990
#   Max FST: 0.203482

# %% [markdown]
# ## Step 4: Select Top FST Variants

# %%
# Select top variants
merged_df, top_snps_file = select_top_fst_variants(
    fst_prefix,
    output_file=str(PATHS.TOP_SNPS_FILE),
    top_n=SITUATIONAL_FILTERS.FST_TOP_N,
)

print(f"\nTop FST variants:")
display(merged_df.head(10))
# Out:
# Found 3 FST files:
#   - SEA_JPT_CN_FST_RESULTS.CN.SEA.fst.var
#   - SEA_JPT_CN_FST_RESULTS.JPT.SEA.fst.var
#   - SEA_JPT_CN_FST_RESULTS.CN.JPT.fst.var
#
# Analyzing: CN.SEA
# Loading FST file: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FST_RESULTS.CN.SEA.fst.var
#    #CHROM    POS               ID  OBS_CT  HUDSON_FST
# 0       1  13116  1:13116[b37]T,G     400   -0.002387
# 1       1  13273  1:13273[b37]G,C     400    0.011534
# 2       1  13289  1:13289[b37]C,T     400   -0.001508
# 3       1  13543  1:13543[b37]T,G     400   -0.001508
# 4       1  14599  1:14599[b37]T,A     400   -0.001660
#               #CHROM           POS    OBS_CT     HUDSON_FST
# count  614759.000000  6.147590e+05  614759.0  600662.000000
# mean        9.093952  7.787213e+07     400.0       0.002505
# std         6.027900  5.847665e+07       0.0       0.006675
# min         1.000000  6.840000e+02     400.0      -0.002510
# 25%         4.000000  2.894938e+07     400.0      -0.001822
# 50%         8.000000  6.717207e+07     400.0       0.000000
# 75%        14.000000  1.163766e+08     400.0       0.004819
# max        22.000000  2.492402e+08     400.0       0.285170
# Total variants: 614759
# NaN FST: 14097
# Negative FST: 273714
# Zero FST: 28355
# Positive FST: 298593
#
# Top 1000 variants:
#         #CHROM        POS                   ID  OBS_CT  HUDSON_FST
# 574876      19   54792079  19:54792079[b37]G,T     400    0.285170
# 147137       4   17813761   4:17813761[b37]G,A     400    0.222120
# 120391       3   86028382   3:86028382[b37]G,T     400    0.216326
# 4028         1   12387655   1:12387655[b37]G,A     400    0.200381
# 131542       3  152553769  3:152553769[b37]C,T     400    0.196495
#
# Analyzing: JPT.SEA
# Loading FST file: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FST_RESULTS.JPT.SEA.fst.var
#    #CHROM    POS               ID  OBS_CT  HUDSON_FST
# 0       1  13116  1:13116[b37]T,G     296    0.047274
# 1       1  13273  1:13273[b37]G,C     296    0.072630
# 2       1  13289  1:13289[b37]C,T     296    0.002611
# 3       1  13543  1:13543[b37]T,G     296    0.002611
# 4       1  14599  1:14599[b37]T,A     296    0.051634
#               #CHROM           POS    OBS_CT     HUDSON_FST
# count  614759.000000  6.147590e+05  614759.0  589780.000000
# mean        9.093952  7.787213e+07     296.0       0.007057
# std         6.027900  5.847665e+07       0.0       0.014378
# min         1.000000  6.840000e+02     296.0      -0.003727
# 25%         4.000000  2.894938e+07     296.0      -0.001379
# 50%         8.000000  6.717207e+07     296.0       0.002611
# 75%        14.000000  1.163766e+08     296.0       0.009662
# max        22.000000  2.492402e+08     296.0       0.386240
# Total variants: 614759
# NaN FST: 24979
# Negative FST: 185273
# Zero FST: 53704
# Positive FST: 350803
#
# Top 1000 variants:
#         #CHROM        POS                    ID  OBS_CT  HUDSON_FST
# 225262       6   31603591    6:31603591[b37]A,G     296    0.386240
# 574876      19   54792079   19:54792079[b37]G,T     296    0.347395
# 537163      17   72054724   17:72054724[b37]C,T     296    0.254177
# 476047      14  106286458  14:106286458[b37]A,G     296    0.250414
# 580886      20   12928988   20:12928988[b37]T,G     296    0.250124
#
# Analyzing: CN.JPT
# Loading FST file: data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_FST_RESULTS.CN.JPT.fst.var
#    #CHROM    POS               ID  OBS_CT  HUDSON_FST
# 0       1  13116  1:13116[b37]T,G     312    0.044101
# 1       1  13273  1:13273[b37]G,C     312    0.027190
# 2       1  13289  1:13289[b37]C,T     312    0.000000
# 3       1  13543  1:13543[b37]T,G     312    0.000000
# 4       1  14599  1:14599[b37]T,A     312    0.064178
#               #CHROM           POS    OBS_CT     HUDSON_FST
# count  614759.000000  6.147590e+05  614759.0  589349.000000
# mean        9.093952  7.787213e+07     312.0       0.003988
# std         6.027900  5.847665e+07       0.0       0.009865
# min         1.000000  6.840000e+02     312.0      -0.003620
# 25%         4.000000  2.894938e+07     312.0      -0.002402
# 50%         8.000000  6.717207e+07     312.0       0.000642
# 75%        14.000000  1.163766e+08     312.0       0.006293
# max        22.000000  2.492402e+08     312.0       0.203482
# Total variants: 614759
# NaN FST: 25410
# Negative FST: 214351
# Zero FST: 48874
# Positive FST: 326124
#
# Top 1000 variants:
#         #CHROM       POS                   ID  OBS_CT  HUDSON_FST
# 507284      16  46426674  16:46426674[b37]T,C     312    0.203482
# 120206       3  83842624   3:83842624[b37]G,A     312    0.196357
# 603341      21  47054067  21:47054067[b37]A,G     312    0.191094
# 526427      17  22261227  17:22261227[b37]G,A     312    0.177473
# 601646      21  42335080  21:42335080[b37]C,G     312    0.173854
# Merged 3 dataframes: 3000 total -> 2508 unique variants
#
# ============================================================
# FST VARIANT SELECTION SUMMARY
# ============================================================
#   Top N per comparison: 1000
#   Number of comparisons: 3
#   Total unique variants: 2508
#
# Variant list saved: data/1000genomes/output_sea_jpt_cn/top_snps.txt
#
# Top FST variants:
#    #CHROM        POS                   ID  OBS_CT  HUDSON_FST
# 0      19   54792079  19:54792079[b37]G,T     400    0.285170
# 1       4   17813761   4:17813761[b37]G,A     400    0.222120
# 2       3   86028382   3:86028382[b37]G,T     400    0.216326
# 3       1   12387655   1:12387655[b37]G,A     400    0.200381
# 4       3  152553769  3:152553769[b37]C,T     400    0.196495
# 5      21   38533017  21:38533017[b37]G,A     400    0.195032
# 6       1   22315762   1:22315762[b37]C,A     400    0.192504
# 7      14   96938945  14:96938945[b37]A,T     400    0.187990
# 8       5   41181491   5:41181491[b37]G,T     400    0.185098
# 9       9  117013044  9:117013044[b37]A,C     400    0.177179

# %%
# Visualize top FST variants
plt.figure(figsize=(10, 5))

plt.hist(merged_df['HUDSON_FST'], bins=30, edgecolor='black', alpha=0.7, color='orange')
plt.xlabel('Hudson FST')
plt.ylabel('Count')
plt.title(f'Distribution of Top {len(merged_df)} FST Variants')
plt.axvline(merged_df['HUDSON_FST'].median(), color='red', linestyle='--', 
            label=f'Median: {merged_df["HUDSON_FST"].median():.4f}')
plt.legend()
plt.show()

# %%
# Convert to BED format
bed_file = str(PATHS.TOP_SNPS_BED)
variants_to_bed_file(top_snps_file, bed_file)
# Out:
# Converted 2508 variants to BED format: data/1000genomes/output_sea_jpt_cn/top_snps.bed
# 2508

# %% [markdown]
# ## Step 5: Extract FST-Selected Variants

# %%
# Extract variants
fst_filtered = extract_fst_variants(
    str(PATHS.PLINK_UNIQUE_IDS),  # Use pfile with unique IDs
    top_snps_file,
    output_pfile=str(PATHS.FST_FILTERED),
)

print(f"\nExtracted variants: {count_variants(fst_filtered)}")
# Out:
# Extracting FST-selected variants...
# Running: plink2 --threads 16 --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids --extract data/1000genomes/output_sea_jpt_cn/top_snps.txt --make-pgen --out data/1000genomes/output_sea_jpt_cn/FST_FILTERED
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/1000genomes/output_sea_jpt_cn/FST_FILTERED.log.
# Options in effect:
#   --extract data/1000genomes/output_sea_jpt_cn/top_snps.txt
#   --make-pgen
#   --out data/1000genomes/output_sea_jpt_cn/FST_FILTERED
#   --pfile data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids
#   --threads 16
#
# Start time: Sun May 24 14:14:49 2026
# 15186 MiB RAM detected, ~4832 available; reserving 4768 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 504 samples (0 females, 0 males, 504 ambiguous; 504 founders) loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.psam.
# 21945146 variants loaded from
# data/1000genomes/output_sea_jpt_cn/SEA_JPT_CN_SNP_MAF_HWE_filtered_unique_ids.pvar.
# Note: No phenotype data present.
# --extract: 2508 variants remaining.
# 2508 variants remaining after main filters.
# Writing data/1000genomes/output_sea_jpt_cn/FST_FILTERED.psam ... done.
# Writing data/1000genomes/output_sea_jpt_cn/FST_FILTERED.pvar ... .
# Writing data/1000genomes/output_sea_jpt_cn/FST_FILTERED.pgen ... done.
# End time: Sun May 24 14:14:56 2026
#
# Extracted variants: 2508

# %% [markdown]
# ## Step 6: PCA Analysis

# %%
# Calculate PCA on FST-selected variants
pca_prefix = calculate_pca(
    fst_filtered,
    output_prefix=str(PATHS.PCA_FILE),
    n_components=10,
)
# Out:
# ============================================================
# SITUATIONAL: PCA Calculation
# ============================================================
#   Components: 10
# Running: plink2 --threads 16 --pfile data/1000genomes/output_sea_jpt_cn/FST_FILTERED --pca 10 --out data/1000genomes/output_sea_jpt_cn/FST_PCA
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/1000genomes/output_sea_jpt_cn/FST_PCA.log.
# Options in effect:
#   --out data/1000genomes/output_sea_jpt_cn/FST_PCA
#   --pca 10
#   --pfile data/1000genomes/output_sea_jpt_cn/FST_FILTERED
#   --threads 16
#
# Start time: Sun May 24 14:14:56 2026
# 15186 MiB RAM detected, ~5086 available; reserving 5022 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 504 samples (0 females, 0 males, 504 ambiguous; 504 founders) loaded from
# data/1000genomes/output_sea_jpt_cn/FST_FILTERED.psam.
# 2508 variants loaded from data/1000genomes/output_sea_jpt_cn/FST_FILTERED.pvar.
# Note: No phenotype data present.
# Calculating allele frequencies... done.
# Constructing GRM: 11172228344045515763687480869197done.
# Extracting eigenvalues and eigenvectors... done.
# --pca: Eigenvectors written to
# data/1000genomes/output_sea_jpt_cn/FST_PCA.eigenvec , and eigenvalues written
# to data/1000genomes/output_sea_jpt_cn/FST_PCA.eigenval .
# End time: Sun May 24 14:14:56 2026
#
# PCA results: data/1000genomes/output_sea_jpt_cn/FST_PCA.eigenvec
# Eigenvalues: data/1000genomes/output_sea_jpt_cn/FST_PCA.eigenval

# %%
# Load PCA results
eigenvec = pd.read_csv(f"{pca_prefix}.eigenvec", sep=r"\s+", header=None)
eigenvec.columns = ["#IID"] + [f"PC{i}" for i in range(1, 11)]

eigenval = pd.read_csv(f"{pca_prefix}.eigenval", header=None)
eigenval.columns = ["eigenvalue"]

# Merge with population labels
pop_df = pd.read_csv(SAMPLES_CSV, header=None)
pop_df.columns = ["#IID", "POP", "SUPER_POP"]

pca_df = eigenvec.merge(pop_df[["#IID", "POP"]], on="#IID")

print(f"PCA results: {len(pca_df)} samples")
display(pca_df.head())
# Out:
# PCA results: 504 samples
#       #IID         PC1         PC2         PC3         PC4          PC5  \
# 0  HG00403  -0.0131303   0.0904353   0.0223836  -0.0557421      0.04559
# 1  HG00404  -0.0173318   0.0740506   0.0181526  -0.0450933  0.000789384
# 2  HG00406    0.006585  0.00222495  -0.0398094  0.00335276   0.00193692
# 3  HG00407  0.00940249   0.0266022  -0.0355688  0.00715026   0.00951505
# 4  HG00409  0.00597755  -0.0132444  -0.0457659  -0.0521078   0.00464405
#
#           PC6          PC7          PC8           PC9        PC10 POP
# 0   0.0600006  -0.00120362   -0.0524783     0.0158865  -0.0617523  CN
# 1    0.117914   -0.0695166   -0.0783008     0.0391397  -0.0211662  CN
# 2   0.0198697   -0.0220723  -0.00261157  -0.000266028  0.00440281  CN
# 3  0.00212463   -0.0220639    0.0178239    -0.0240718   0.0063922  CN
# 4   0.0596236    0.0391185    0.0513919    0.00971359   0.0380482  CN

# %%
# Plot PC1 vs PC2
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# PC1 vs PC2
sns.scatterplot(
    data=pca_df,
    x="PC1", y="PC2",
    hue="POP",
    palette="tab10",
    s=60, alpha=0.8,
    ax=axes[0],
)
axes[0].set_xlabel("PC1")
axes[0].set_ylabel("PC2")
axes[0].set_title("PCA: PC1 vs PC2")
axes[0].legend(title="Population")
axes[0].grid(True, linestyle="--", alpha=0.5)

# PC2 vs PC3
sns.scatterplot(
    data=pca_df,
    x="PC2", y="PC3",
    hue="POP",
    palette="tab10",
    s=60, alpha=0.8,
    ax=axes[1],
)
axes[1].set_xlabel("PC2")
axes[1].set_ylabel("PC3")
axes[1].set_title("PCA: PC2 vs PC3")
axes[1].legend(title="Population")
axes[1].grid(True, linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %%
# Scree plot
plt.figure(figsize=(10, 5))

plt.bar(range(1, len(eigenval) + 1), eigenval["eigenvalue"], color='skyblue', edgecolor='black')
plt.xlabel("Principal Component")
plt.ylabel("Eigenvalue")
plt.title("Scree Plot: Variance Explained by Each PC")
plt.xticks(range(1, len(eigenval) + 1))
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add cumulative variance line
cumvar = eigenval["eigenvalue"].cumsum() / eigenval["eigenvalue"].sum() * 100
ax2 = plt.twinx()
ax2.plot(range(1, len(eigenval) + 1), cumvar, 'r-o', label='Cumulative %')
ax2.set_ylabel('Cumulative Variance (%)')
ax2.legend(loc='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary

# %%
print("="*60)
print("FST AND PCA SUMMARY")
print("="*60)
print(f"\nFST Analysis:")
print(f"  Population comparisons: {len(all_fst)}")
print(f"  Top N per comparison: {SITUATIONAL_FILTERS.FST_TOP_N}")
print(f"  Total unique top variants: {len(merged_df)}")
print(f"\nPCA:")
print(f"  Samples: {len(pca_df)}")
print(f"  Components: 10")
print(f"  Variance explained (PC1+PC2): {cumvar.iloc[1]:.1f}%")
print(f"\nOutput files:")
print(f"  - Top SNPs: {top_snps_file}")
print(f"  - BED file: {bed_file}")
print(f"  - FST filtered pfile: {fst_filtered}")
print(f"  - PCA results: {pca_prefix}.eigenvec")
print(f"\nNext step: Run 04_ml_training.ipynb")
# Out:
# ============================================================
# FST AND PCA SUMMARY
# ============================================================
#
# FST Analysis:
#   Population comparisons: 3
#   Top N per comparison: 1000
#   Total unique top variants: 2508
#
# PCA:
#   Samples: 504
#   Components: 10
#   Variance explained (PC1+PC2): 58.3%
#
# Output files:
#   - Top SNPs: data/1000genomes/output_sea_jpt_cn/top_snps.txt
#   - BED file: data/1000genomes/output_sea_jpt_cn/top_snps.bed
#   - FST filtered pfile: data/1000genomes/output_sea_jpt_cn/FST_FILTERED
#   - PCA results: data/1000genomes/output_sea_jpt_cn/FST_PCA.eigenvec
#
# Next step: Run 04_ml_training.ipynb
